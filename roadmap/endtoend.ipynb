# %%
print("roshan")
print("this is the jupyter ")
# Out:
# roshan
# this is the jupyter

# %%
import requests
from pathlib import Path
import tarfile
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"
def fetch_housing_data(url=HOUSING_URL, extract_to="datasets/housing"):
    path = Path(extract_to)
    path.mkdir(parents=True,exist_ok=True)
    tgz_path = path / "housing.tgz"
    print("Downloading dataset...")
    response = requests.get(url)
    response.raise_for_status()  
    tgz_path.write_bytes(response.content)
    print(f"Saved to {tgz_path}")
    print("Extracting dataset...")
    with tarfile.open(tgz_path) as housing_tgz:
        housing_tgz.extractall(path=path)
    print(f"Extracted to {path}")
    print("done")



fetch_housing_data()
# Out:
# ...
# Saved to datasets/housing/housing.tgz
# Extracting dataset...
# Extracted to datasets/housing
# done

# %%
# print("testing karnel")

# %%
import pandas as pd 
data=pd.read_csv("datasets/housing/housing.csv")
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
data

# %%
# importing the matplot for the ploting the graph 
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(20,15))
plt.show()
